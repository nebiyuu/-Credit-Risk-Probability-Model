# %%
import pandas as pd
import numpy as np

# %%
cleaned_data = pd.read_csv('../data/processed/cleaned_data.csv')
output_data = pd.read_csv('../data/processed/output.csv')

# %%
output_data.head()
# Out:
#         CustomerId  total_amount  customer_transactions  fraud_transactions  \
# 0  CustomerId_4406       10000.0                    119                 NaN
# 1  CustomerId_4683       10000.0                      2                 NaN
# 2   CustomerId_988       30400.0                     38                 NaN
# 3  CustomerId_1432        4775.0                      1                 NaN
# 4  CustomerId_2858       32000.0                     29                 NaN
#
#    total_fraud_amount  fraud_ratio  fraud_amount_ratio  fraud_frequency_score  \
# 0                 NaN          NaN                 NaN                    NaN
# 1                 NaN          NaN                 NaN                    NaN
# 2                 NaN          NaN                 NaN                    NaN
# 3                 NaN          NaN                 NaN                    NaN
# 4                 NaN          NaN                 NaN                    NaN
#
#    high_value_fraud      last_transaction_date
# 0                 0  2019-02-12 10:24:40+00:00
# 1                 0  2018-11-24 08:30:25+00:00
# 2                 0  2019-02-08 07:53:33+00:00
# 3                 0  2018-11-15 03:35:10+00:00
# 4                 0  2019-02-08 06:51:39+00:00

# %%
cleaned_data['TransactionStartTime'] = pd.to_datetime(cleaned_data['TransactionStartTime'])
#get last transaction date in cleaned_data
ref_date = cleaned_data['TransactionStartTime'].max() + pd.Timedelta(days=1)

# %%
output_data.columns
# Out:
# Index(['CustomerId', 'total_amount', 'customer_transactions',
#        'fraud_transactions', 'total_fraud_amount', 'fraud_ratio',
#        'fraud_amount_ratio', 'fraud_frequency_score', 'high_value_fraud',
#        'last_transaction_date'],
#       dtype='object')

# %%
rfm = cleaned_data.groupby('CustomerId').agg({
    'TransactionStartTime': lambda x: (ref_date - x.max()).days,  # Recency
    'TransactionId': 'count',                                     # Frequency
    'Amount': 'sum'                                               # Monetary
}).reset_index()

# %%
output_data['last_transaction_date'] = pd.to_datetime(output_data['last_transaction_date'])

ref_date = output_data['last_transaction_date'].max() + pd.Timedelta(days=1)
output_data['Recency'] = (ref_date - output_data['last_transaction_date']).dt.days
output_data['Frequency'] = output_data['customer_transactions']
output_data['Monetary'] = output_data['total_amount']

# %%
# print only rmf cols  head of output_data
rmf = output_data[['CustomerId', 'Recency', 'Frequency', 'Monetary']]
print(rmf.head())
# Out:
#         CustomerId  Recency  Frequency  Monetary
# 0  CustomerId_4406        1        119   10000.0
# 1  CustomerId_4683       82          2   10000.0
# 2   CustomerId_988        6         38   30400.0
# 3  CustomerId_1432       91          1    4775.0
# 4  CustomerId_2858        6         29   32000.0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

rfm_scaled = StandardScaler().fit_transform(output_data[['Recency', 'Frequency', 'Monetary']])
kmeans = KMeans(n_clusters=3, random_state=42)
output_data['cluster'] = kmeans.fit_predict(rfm_scaled)

# %%
cluster_profile = output_data.groupby('cluster')[['Recency', 'Frequency', 'Monetary']].mean()
high_risk_cluster = cluster_profile.sort_values(['Recency', 'Frequency', 'Monetary'], ascending=[False, True, True]).index[0]
output_data['credit_risk'] = output_data['cluster'].apply(lambda x: 1 if x == high_risk_cluster else 0)

# %%
output_data.head()
# Out:
#         CustomerId  total_amount  customer_transactions  fraud_transactions  \
# 0  CustomerId_4406       10000.0                    119                 NaN
# 1  CustomerId_4683       10000.0                      2                 NaN
# 2   CustomerId_988       30400.0                     38                 NaN
# 3  CustomerId_1432        4775.0                      1                 NaN
# 4  CustomerId_2858       32000.0                     29                 NaN
#
#    total_fraud_amount  fraud_ratio  fraud_amount_ratio  fraud_frequency_score  \
# 0                 NaN          NaN                 NaN                    NaN
# 1                 NaN          NaN                 NaN                    NaN
# 2                 NaN          NaN                 NaN                    NaN
# 3                 NaN          NaN                 NaN                    NaN
# 4                 NaN          NaN                 NaN                    NaN
#
#    high_value_fraud     last_transaction_date  Recency  Frequency  Monetary  \
# 0                 0 2019-02-12 10:24:40+00:00        1        119   10000.0
# 1                 0 2018-11-24 08:30:25+00:00       82          2   10000.0
# 2                 0 2019-02-08 07:53:33+00:00        6         38   30400.0
# 3                 0 2018-11-15 03:35:10+00:00       91          1    4775.0
# 4                 0 2019-02-08 06:51:39+00:00        6         29   32000.0
#
#    cluster  credit_risk
# 0        1            0
# 1        0            1
# 2        1            0
# 3        0            1
# 4        1            0

# %%
output_data.columns
#cluster unique values
output_data['cluster'].unique()
# sort cluster based on credit risk
output_data.sort_values(by='credit_risk', ascending=False, inplace=True)
output_data.head()
# Out:
#            CustomerId  total_amount  customer_transactions  \
# 2455  CustomerId_1972     531360.00                      2
# 2454  CustomerId_1986     955862.25                      2
# 2453  CustomerId_1231      49036.00                      1
# 2452  CustomerId_4457      18750.00                      1
# 2451  CustomerId_4332       8100.00                      1
#
#       fraud_transactions  total_fraud_amount  fraud_ratio  fraud_amount_ratio  \
# 2455                 NaN                 NaN          NaN                 NaN
# 2454                 NaN                 NaN          NaN                 NaN
# 2453                 NaN                 NaN          NaN                 NaN
# 2452                 NaN                 NaN          NaN                 NaN
# 2451                 NaN                 NaN          NaN                 NaN
#
#       fraud_frequency_score  high_value_fraud     last_transaction_date  \
# 2455                    NaN                 0 2019-01-08 09:47:27+00:00
# 2454                    NaN                 0 2019-01-08 08:48:11+00:00
# 2453                    NaN                 0 2019-01-08 08:25:57+00:00
# 2452                    NaN                 0 2019-01-08 08:09:39+00:00
# 2451                    NaN                 0 2019-01-08 06:23:56+00:00
#
#       Recency  Frequency   Monetary  cluster  credit_risk
# 2455       37          2  531360.00        0            1
# 2454       37          2  955862.25        0            1
# 2453       37          1   49036.00        0            1
# 2452       37          1   18750.00        0            1
# 2451       37          1    8100.00        0            1
